# %%
#Remove Duplicate Records
vitals_df = vitals_df.dropDuplicates()
details_df = details_df.dropDuplicates()
device_df = device_df.dropDuplicates()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File <command-6022763873375093>, line 1
# ----> 1 vitals_df = vitals_df.dropDuplicates()
#       2 details_df = details_df.dropDuplicates()
#       3 device_df = device_df.dropDuplicates()
#
# NameError: name 'vitals_df' is not defined

# %%
#Handle Null Readings
from pyspark.sql.functions import col

vitals_df = vitals_df \
    .withColumn("heart_rate", col("heart_rate").cast("int")) \
    .withColumn("oxygen_level", col("oxygen_level").cast("int")) \
    .withColumn("temperature", col("temperature").cast("double"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File <command-6022763873375095>, line 4
#       2 from pyspark.sql.functions import col
# ----> 4 vitals_df = vitals_df \
#       5     .withColumn("heart_rate", col("heart_rate").cast("int")) \
#       6     .withColumn("oxygen_level", col("oxygen_level").cast("int")) \
#       7     .withColumn("temperature", col("temperature").cast("double"))
#
# NameError: name 'vitals_df' is not defined

# %%
#Remove rows with critical nulls:
vitals_df = vitals_df.dropna(subset=["heart_rate", "oxygen_level", "temperature"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File <command-8733654078839220>, line 1
# ----> 1 vitals_df = vitals_df.dropna(subset=["heart_rate", "oxygen_level", "temperature"])
#
# NameError: name 'vitals_df' is not defined

# %%
#Option B — Fill with medically safe defaults:
vitals_df = vitals_df.fillna({
    "heart_rate": 0,
    "oxygen_level": 0,
    "temperature": 0
})

# %%
#andle Incorrect Values
vitals_df = vitals_df.filter(
    (col("heart_rate") > 0) & 
    (col("oxygen_level") > 0) & 
    (col("temperature") > 0)
)

# %%
#Handle Missing Patient Info
details_df = details_df.dropna(subset=["patient_id", "name"])
